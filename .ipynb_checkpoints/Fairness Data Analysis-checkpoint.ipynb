# %% [markdown]
# # 1 Import Libraries

# %%
# Pandas is the main library used for exploratory data analysis
# Pandas is built on top of numpy 
# Numpy allows fast advanced mathematical operations on large amount of data
from __future__ import division

import numpy as np
import pandas as pd

# %% [markdown]
# # 2 Load Data

# %%
# Load the data from the web
# url = 'data.csv'
url = 'new-data.csv'

col_names = [
          'Unique Id',             
            'Survey Id', 
             'Keyword Id',
             'Keyword Content',
             'Country Of Origin Id',
             'Country Of Origin Label',
             'Country Id',
             'Country Label'
             'Province Id',
             'Province Label'
             'Age Group Id',
             'Age Group Label',
             'Gender Label',
             'Share Device',
             'Mobile Type',
             'Degree',
             'Rank Pandemic',
             'Source Information Id', 
             'Source Information Label',
             'Result Item Rank',
             'Result Item Title',
             'Result Item Metadesc',
             'Result Item Created At',
             'Result Item Full Url',
             'Result Item Full Domain',
             'Google Tracked Country',
             'Google Tracked Address',
             'Result Item Openrank',
             'Keyword Openrank Average',
             'Survey Openrank Average']

fairness_df = pd.read_csv(url, header=1, names=col_names)

fairness_df.info()

fairness_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 4690 entries, (2, 4, 9) to (4691, 148, 10)
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unique Id                   4690 non-null   object
#  1   Survey Id                   4690 non-null   int64
#  2   Keyword Id                  4690 non-null   object
#  3   Keyword Content             4690 non-null   int64
#  4   Country Of Origin Id        4690 non-null   object
#  5   Country Of Origin Label     4690 non-null   int64
#  6   Country Id                  4690 non-null   object
#  7   Country LabelProvince Id    4690 non-null   int64
#  8   Province LabelAge Group Id  4690 non-null   object
#  9   Age Group Label             4690 non-null   object
#  10  Gender Label                4690 non-null   object
#  11  Share Device                4690 non-null   object
#  12  Mobile Type                 4690 non-null   object
#  13  Degree                      4690 non-null   int64
#  14  Rank Pandemic               4690 non-null   int64
#  15  Source Information Id       4690 non-null   object
#  16  Source Information Label    4690 non-null   int64
#  17  Result Item Rank            4690 non-null   object
#  18  Result Item Title           4690 non-null   object
#  19  Result Item Metadesc        2411 non-null   object
#  20  Result Item Created At      4690 non-null   object
#  21  Result Item Full Url        4690 non-null   object
#  22  Result Item Full Domain     1624 non-null   object
#  23  Google Tracked Country      3980 non-null   object
#  24  Google Tracked Address      4690 non-null   int64
#  25  Result Item Openrank        4690 non-null   float64
#  26  Keyword Openrank Average    4690 non-null   float64
#  27  Survey Openrank Average     4690 non-null   object
# dtypes: float64(2), int64(8), object(18)
# memory usage: 1.2+ MB
#                                        Unique Id  Survey Id Keyword Id  \
# 2 4 9  is hydroxychloroquine effective for covid         60    Germany
# 3 4 9  is hydroxychloroquine effective for covid         60    Germany
# 4 4 9  is hydroxychloroquine effective for covid         60    Germany
# 5 4 9  is hydroxychloroquine effective for covid         60    Germany
# 6 4 9  is hydroxychloroquine effective for covid         60    Germany
#
#        Keyword Content Country Of Origin Id  Country Of Origin Label  \
# 2 4 9               60              Germany                      954
# 3 4 9               60              Germany                      954
# 4 4 9               60              Germany                      954
# 5 4 9               60              Germany                      954
# 6 4 9               60              Germany                      954
#
#       Country Id  Country LabelProvince Id Province LabelAge Group Id  \
# 2 4 9     Hessen                         4                      35-44
# 3 4 9     Hessen                         4                      35-44
# 4 4 9     Hessen                         4                      35-44
# 5 4 9     Hessen                         4                      35-44
# 6 4 9     Hessen                         4                      35-44
#
#       Age Group Label  ...                                  Result Item Title  \
# 2 4 9           other  ...  Sep 22, 2020 -  Hydroxychloroquine, an FDA-app...
# 3 4 9           other  ...  Arshad et al. show evidence for reduced mortal...
# 4 4 9           other  ...  There are studies looking at using these drugs...
# 5 4 9           other  ...  Hydroxychloroquine has been suggested for the ...
# 6 4 9           other  ...  Jul 1, 2020 -  FDA cautions against use of hyd...
#
#       Result Item Metadesc                             Result Item Created At  \
# 2 4 9         Sep 22, 2020  https://www.drugs.com/medical-answers/hydroxyc...
# 3 4 9                  NaN  https://www.ijidonline.com/article/S1201-9712(...
# 4 4 9                  NaN                  https://www.bbc.com/news/51980731
# 5 4 9                  NaN            https://www.nps.org.au/hcq-and-covid-19
# 6 4 9          Jul 1, 2020  https://www.fda.gov/drugs/drug-safety-and-avai...
#
#        Result Item Full Url  Result Item Full Domain Google Tracked Country  \
# 2 4 9             drugs.com                  Germany             Heppenheim
# 3 4 9        ijidonline.com                  Germany             Heppenheim
# 4 4 9               bbc.com                  Germany             Heppenheim
# 5 4 9            nps.org.au                  Germany             Heppenheim
# 6 4 9               fda.gov                  Germany             Heppenheim
#
#        Google Tracked Address Result Item Openrank Keyword Openrank Average  \
# 2 4 9                      77                72.44                    71.56
# 3 4 9                      51                72.44                    71.56
# 4 4 9                      81                72.44                    71.56
# 5 4 9                      60                72.44                    71.56
# 6 4 9                      82                72.44                    71.56
#
#                                  Survey Openrank Average
# 2 4 9  fairness.datasciencevn.com/uploads/html/4-9-16...
# 3 4 9  fairness.datasciencevn.com/uploads/html/4-9-16...
# 4 4 9  fairness.datasciencevn.com/uploads/html/4-9-16...
# 5 4 9  fairness.datasciencevn.com/uploads/html/4-9-16...
# 6 4 9  fairness.datasciencevn.com/uploads/html/4-9-16...
#
# [5 rows x 28 columns]

# %% [markdown]
# # Visualization

# %% [markdown]
# ## Gender

# %%
gender = fairness_df['Gender Label']

gender.head()
# Out:
# 2  4  9    NO
# 3  4  9    NO
# 4  4  9    NO
# 5  4  9    NO
# 6  4  9    NO
# Name: Gender Label, dtype: object

# %% [markdown]
# # Correlations between pairs of variables

# %%
# 1. Use the corr() function from the dataframe to compute the correlations and display as text
corr = fairness_df.corr()
print(type(corr))
print(corr)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                           Survey Id  Keyword Content  Country Of Origin Label  \
# Survey Id                  1.000000         0.999111                 0.998926
# Keyword Content            0.999111         1.000000                 0.999876
# Country Of Origin Label    0.998926         0.999876                 1.000000
# Country LabelProvince Id   0.223163         0.222005                 0.222646
# Degree                    -0.013158        -0.025002                -0.024442
# Rank Pandemic             -0.173207        -0.180979                -0.182328
# Source Information Label   0.022671         0.023408                 0.023931
# Google Tracked Address     0.027657         0.027640                 0.027756
# Result Item Openrank      -0.071417        -0.069326                -0.069013
# Keyword Openrank Average  -0.163933        -0.163215                -0.162648
#
#                           Country LabelProvince Id    Degree  Rank Pandemic  \
# Survey Id                                 0.223163 -0.013158      -0.173207
# Keyword Content                           0.222005 -0.025002      -0.180979
# Country Of Origin Label                   0.222646 -0.024442      -0.182328
# Country LabelProvince Id                  1.000000  0.174068       0.177723
# Degree                                    0.174068  1.000000      -0.096273
# Rank Pandemic                             0.177723 -0.096273       1.000000
# Source Information Label                  0.029852  0.009928      -0.030170
# Google Tracked Address                    0.007235 -0.002210      -0.007367
# Result Item Openrank                     -0.019733 -0.030756      -0.007577
# Keyword Openrank Average                  0.116082  0.072575       0.156774
#
#                           Source Information Label  Google Tracked Address  \
# Survey Id                                 0.022671                0.027657
# Keyword Content                           0.023408                0.027640
# Country Of Origin Label                   0.023931                0.027756
# Country LabelProvince Id                  0.029852                0.007235
# Degree                                    0.009928               -0.002210
# Rank Pandemic                            -0.030170               -0.007367
# Source Information Label                  1.000000               -0.166869
# Google Tracked Address                   -0.166869                1.000000
# Result Item Openrank                      0.140487                0.037404
# Keyword Openrank Average                  0.073177               -0.001330
#
#                           Result Item Openrank  Keyword Openrank Average
# Survey Id                            -0.071417                 -0.163933
# Keyword Content                      -0.069326                 -0.163215
# Country Of Origin Label              -0.069013                 -0.162648
# Country LabelProvince Id             -0.019733                  0.116082
# Degree                               -0.030756                  0.072575
# Rank Pandemic                        -0.007577                  0.156774
# Source Information Label              0.140487                  0.073177
# Google Tracked Address                0.037404                 -0.001330
# Result Item Openrank                  1.000000                  0.048262
# Keyword Openrank Average              0.048262                  1.000000

# %%
sns.set(style='ticks')
#plt.figure(figsize=(8,16)) #figsize(width, height) in inches - default(6.4, 4.8) - customise as required
sns.pairplot(fairness_df, kind="reg") # kind="reg" means plot the regression line as well

# If you want to save the graph to disk
plt.tight_layout() # automatically adjusts subplot to fit in the figure area
plt.savefig('correlation-pairplot.png', dpi=300) # dpi=300 is print quality
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-5a6e2beaaafe> in <module>
# ----> 1 sns.set(style='ticks')
#       2 #plt.figure(figsize=(8,16)) #figsize(width, height) in inches - default(6.4, 4.8) - customise as required
#       3 sns.pairplot(fairness_df, kind="reg") # kind="reg" means plot the regression line as well
#       4
#       5 # If you want to save the graph to disk
#
# NameError: name 'sns' is not defined
