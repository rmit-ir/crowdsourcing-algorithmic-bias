# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# pd.set_option('display.max_columns',100)
# pd.set_option('display.max_rows',100)
sns.set(rc={'figure.figsize':(10,8)})
sns.set_style("ticks")
 
# Smallest context:
sns.set_context("paper")

# %%
df = pd.read_csv("../data.csv",index_col=0)

# %%
df.columns
# Out:
# Index(['Survey Id', 'Keyword Id', 'Keyword Content', 'Country Of Origin Id',
#        'Country Of Origin Label', 'Country Id', 'Country Label', 'Province Id',
#        'Province Label', 'Age Group Id', 'Age Group Label', 'Gender Label',
#        'Share Device', 'Mobile Type', 'Degree', 'Rank Pandemic',
#        'Source Information Id', 'Source Information Label', 'Result Item Rank',
#        'Result Item Title', 'Result Item Metadesc', 'Result Item Created At',
#        'Result Item Full Url', 'Result Item Full Domain',
#        'Google Tracked Country', 'Google Tracked Address',
#        'Result Item Openrank', 'Keyword Openrank Average',
#        'Survey Openrank Average', 'Html File'],
#       dtype='object')

# %%
participants = df.groupby("Survey Id").first()

#Age:
#print(participants.count())

print(participants['Age Group Label'].value_counts())
sns.countplot(participants['Age Group Label'])
plt.show()

#Country:
participants['Country Label'].value_counts()

print(participants['Gender Label'].value_counts())
sns.countplot(participants['Gender Label'])
plt.show()

print(participants['Share Device'].value_counts())
sns.countplot(participants['Share Device'])
plt.show()
print(participants['Degree'].value_counts())
sns.countplot(participants['Degree'])
plt.show()
#participants['Mobile Type'].value_counts()
#sns.countplot(participants['Mobile Type'])


#df.groupby("Survey Id")[['Age Group Label']].value_counts()
# Out:
# 25-34    29
# 35-44    12
# 45-54     6
# 55-64     1
# 65+       1
# 18-24     1
# Name: Age Group Label, dtype: int64
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# na        14
# other     13
# female    12
# male      11
# Name: Gender Label, dtype: int64
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# NO     41
# YES     9
# Name: Share Device, dtype: int64
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# College degree/bachelor’s degree                                                                            32
# Some college (some community college, associate’s degree)                                                    7
# Postgraduate or professional degree, including master’s, doctorate, medical or law degree                    6
# Some postgraduate or professional schooling, no postgraduate degree                                          4
# High school graduate or GED (includes technical/vocational training that doesn’t towards college credit)     1
# Name: Degree, dtype: int64
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
## Country

#df1 = df.groupby("Survey Id")[["Country Label"]].value_agg("max") 
df1 = participants
sns.countplot(df1["Country Label"])
#plt.title("Surveys in Country",fontsize=20) 
plt.ylabel("# Participants",fontsize=20) 
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel("Country of Residence", fontsize=20)
#plt.show() 
plt.savefig('country_of_residence.pdf')
# Out:
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ## How many surveys were taken from each age group?

# %%
plt.figure(figsize=(10,8))
df1 = df.groupby("Survey Id")[["Age Group Id"]].agg("mean")
sns.countplot(df1["Age Group Id"])
plt.ylabel("Number of Surveys")
plt.title("Age Groups Participation in Surveys",fontsize=18)
plt.xticks([0,1,2,3,4,5,6],['18-24', '25-34','35-44','45-54','55-64','65+' ])
plt.show()
# Out:
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/sr/3v89p_y1759cyf5s1jmbyvgc0000gp/T/ipykernel_70610/3217478919.py in <module>
#       4 plt.ylabel("Number of Surveys")
#       5 plt.title("Age Groups Participation in Surveys",fontsize=18)
# ----> 6 plt.xticks([0,1,2,3,4,5,6],['18-24', '25-34','35-44','45-54','55-64','65+' ])
#       7 plt.show()
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/matplotlib/pyplot.py in xticks(ticks, labels, **kwargs)
#    1812         labels = ax.get_xticklabels()
#    1813     else:
# -> 1814         labels = ax.set_xticklabels(labels, **kwargs)
#    1815     for l in labels:
#    1816         l.update(kwargs)
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/matplotlib/axes/_base.py in wrapper(self, *args, **kwargs)
#      71
#      72         def wrapper(self, *args, **kwargs):
# ---> 73             return get_method(self)(*args, **kwargs)
#      74
#      75         wrapper.__module__ = owner.__module__
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/matplotlib/axis.py in _set_ticklabels(self, labels, fontdict, minor, **kwargs)
#    1793         if fontdict is not None:
#    1794             kwargs.update(fontdict)
# -> 1795         return self.set_ticklabels(labels, minor=minor, **kwargs)
#    1796
#    1797     def set_ticks(self, ticks, *, minor=False):
#
# /usr/local/Caskroom/miniconda/base/lib/python3.7/site-packages/matplotlib/axis.py in set_ticklabels(self, ticklabels, minor, **kwargs)
#    1715             if len(locator.locs) != len(ticklabels) and len(ticklabels) != 0:
#    1716                 raise ValueError(
# -> 1717                     "The number of FixedLocator locations"
#    1718                     f" ({len(locator.locs)}), usually from a call to"
#    1719                     " set_ticks, does not match"
#
# ValueError: The number of FixedLocator locations (7), usually from a call to set_ticks, does not match the number of ticklabels (6).

# %% [markdown]
# ## Main source of information in most Surveys?

# %%
df2 = df.groupby("Survey Id")[["Source Information Label"]].agg('max')
plt.figure(figsize=(10,8))
plt.pie(df2["Source Information Label"].value_counts().values,
       labels = df2["Source Information Label"].value_counts().index,
        autopct='%1.1f%%',textprops={'fontsize': 14})
plt.title("Contribution of Different Sources in Covid-19 Information",fontsize=22)
plt.show()

# %% [markdown]
# ## How people ranked pandemic?

# %%
df3 = df.groupby("Survey Id")[["Rank Pandemic"]].agg("mean")
sns.countplot(df3["Rank Pandemic"])
plt.ylabel("Number of Surveys")
plt.title("Surveys Ranked by People",fontsize=18)
plt.show()

# %% [markdown]
# ## How people of USA ranked Pandemic?

# %%
df4 = df[df["Country Label"] == "United States"].groupby("Survey Id")[["Rank Pandemic"]].agg("mean")
sns.countplot(df4["Rank Pandemic"])
plt.ylabel("Number of Surveys")
plt.title("Surveys Ranked by People",fontsize=18)
plt.show()

# %% [markdown]
# ## Male and Female participation in Survey?

# %%
df5 = df.groupby("Survey Id")[["Gender Label"]].agg('max')
male_counts = df5[df5['Gender Label']=='male'].shape[0]
female_counts = df5[df5['Gender Label']=='female'].shape[0]

plt.title("Male and Female Participation in Surveys",fontsize=18)
plt.bar(["Male","Female"],[male_counts,female_counts])
plt.ylabel("Number of Surveys",fontsize=12)
plt.show()

# %% [markdown]
# ## Relation of Share Device column with Gender Column?

# %%
df6 = df.groupby("Survey Id")[["Gender Label","Share Device"]].agg('max')

plt.title("Relation between Share Device and Gender Column",fontsize=18)
sns.countplot(x="Gender Label",hue="Share Device",data=df6)
plt.ylabel("Device Count",fontsize=12)
plt.show()

# %% [markdown]
# ## Did majority Collage Degree students ranked pandemic above 5?

# %%
df7 = df[df["Degree"]=="College degree/bachelor’s degree"].groupby("Survey Id")[["Rank Pandemic"]].agg("max")
df7["above 5"] = None
df7.loc[df7["Rank Pandemic"] > 5,"above 5"] = 1
df7.loc[df7["Rank Pandemic"] <= 5,"above 5"] = 0
sns.countplot(df7["above 5"])
plt.title("Collage Degree Students Ranked Pandemic Above 5",fontsize=18)
plt.ylabel("Pandemic Ranked Above 5",fontsize=12)
plt.xticks([0,1],["Below 5","Above 5"])
plt.show()

# %% [markdown]
# ## What is the Average Open Rank of Surveys?

# %%
df8 = df.groupby("Survey Id")[["Survey Openrank Average"]].agg("max")
average_openrank_of_all_surveys = df8["Survey Openrank Average"].mean()
print("Average of Openrank of All Surveys is : {}".format(average_openrank_of_all_surveys))
